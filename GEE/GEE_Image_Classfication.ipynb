# %% [markdown]
# # 基于GEE进行图像处理，并将结果并进行服务发布

# %% [markdown]
# ![u=4046717626,1991896681&fm=26&gp=0.jpg](attachment:u=4046717626,1991896681&fm=26&gp=0.jpg)

# %% [markdown]
# ## 1) 将本地tif上传到谷歌硬盘

# %% [markdown]
# ## 2)读取影像，进行图像分类

# %% [markdown]
# ## 3)从各个硬盘上将结果文件下载到本地

# %% [markdown]
# ## 4)基于Geoserver动态发布分类结果
